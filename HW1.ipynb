# %% [markdown]
# <a href="https://colab.research.google.com/github/41371232H/PL_Repo/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **日常支出速算與分攤（作業一）**
# 目標：從 Sheet 讀「消費紀錄」→ 計總額/分類小計/AA 分攤 → 寫回 Sheet Summary 分頁。
#
# AI 點子（可選）：請模型總結本週花錢習慣與建議（例如「外食過多」）。
#
# Sheet 欄位：date, category, item, amount, payer
# https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?gid=0#gid=0

# %% [markdown]
# # **歷程記錄**

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)
total = 0;

# %%
import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing')

# %%
# 從 gsheets 的 All-whiteboard-device 載入 sheets
sheets = gsheets.worksheet('工作表1').get_all_values()
# 將 sheets1 資料載入 pd 的 DataFrame 進行分析
df = pd.DataFrame(sheets[1:], columns=sheets[0])
# 取得最前面的5筆資料
df.head()
# Out:
#            日期     時間 品項   金額  總支出
# 0  2025-10-11  12:10  M  100  100

# %%
import datetime
# 讓使用者輸入資料
date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
# 檢查日期格式是否正確
datetime.datetime.strptime(date_str, '%Y-%m-%d')

time_str = input("請輸入時間 (格式：HH:MM): ")
# 檢查時間格式是否正確
datetime.datetime.strptime(time_str, '%H:%M')

item = input("請輸入品項: ")
amount = float(input("請輸入金額: "))
total = total + amount;
# Out:
# 請輸入日期 (格式：YYYY-MM-DD): 2025-11-11
# 請輸入時間 (格式：HH:MM): 12:10
# 請輸入品項: L
# 請輸入金額: 40

# %%
# 創建一個新的 DataFrame 來代表你要新增的資料
new_data = pd.DataFrame([{
    '日期': date_str,
    '時間': time_str,
    '品項': item,
    '金額': amount,
    '總支出': total
}])

# 使用 concat() 將新資料合併到舊的 df 中
df = pd.concat([df, new_data], ignore_index=True)

# %%
# 將 DataFrame 轉換成列表的列表 (list of lists)，這是 gspread 支援的資料格式
#data_to_write = df.values.tolist()
# 第一步：取得工作表物件
#worksheet = gsheets.worksheet('工作表1')
# 第二步：將資料寫入工作表
#worksheet.append_rows(values=data_to_write, value_input_option='USER_ENTERED')

# 第一步：取得工作表物件
worksheet = gsheets.worksheet('工作表1')

# 第二步：只寫入新的一列，而不是整個 df
new_row = [date_str, time_str, item, amount, total]
worksheet.append_row(new_row, value_input_option='USER_ENTERED')

print("資料已成功寫入 Google 工作表！")
# Out:
# 資料已成功寫入 Google 工作表！

# %%
from google.colab import auth
auth.authenticate_user()
import gspread
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)
total = 0;
number = 0;
import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing')
# 從 gsheets 的 All-whiteboard-device 載入 sheets
sheets = gsheets.worksheet('工作表1').get_all_values()
# 將 sheets1 資料載入 pd 的 DataFrame 進行分析
df = pd.DataFrame(sheets[1:], columns=sheets[0])
# 取得最前面的5筆資料
df.head()
import datetime
# 讓使用者輸入資料
date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
# 檢查日期格式是否正確 datetime.datetime.strptime(date_str, '%Y-%m-%d')
time_str = input("請輸入時間 (格式：HH:MM): ")
# 檢查時間格式是否正確 datetime.datetime.strptime(time_str, '%H:%M')
item = input("請輸入品項: ")
amount = float(input("請輸入金額: "))
total = total + amount;
# 創建一個新的 DataFrame 來代表你要新增的資料
new_data = pd.DataFrame([{ '日期': date_str, '時間': time_str, '品項': item, '金額': amount, '總支出': total }])
# 使用 concat() 將新資料合併到舊的 df 中
df = pd.concat([df, new_data], ignore_index=True)
# 將 DataFrame 轉換成列表的列表 (list of lists)，這是 gspread 支援的資料格式
data_to_write = df.values.tolist()
# 第一步：取得工作表物件
worksheet = gsheets.worksheet('工作表1')
# 第二步：將資料寫入工作表
new_row = [date_str, time_str, item, amount, total]
worksheet.append_row(new_row, value_input_option='USER_ENTERED')
print("資料已成功寫入 Google 工作表！")
# Out:
# 請輸入日期 (格式：YYYY-MM-DD): 2025-01-01
# 請輸入時間 (格式：HH:MM): 12:30
# 請輸入品項: L
# 請輸入金額: 100
# /tmp/ipython-input-2027182674.py:30: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_data], ignore_index=True)
# 資料已成功寫入 Google 工作表！

# %%
import datetime
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# Google 驗證
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 連線到 Google Sheet
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing')
worksheet = gsheets.worksheet('工作表1')

# 讀取最後一筆「總支出」
rows = worksheet.get_all_values()
if len(rows) > 1 and rows[-1][4] != '':
    total = float(rows[-1][4])
else:
    total = 0

# while 迴圈：顯示選單
number = 0
while number != 5:
    print("\n====== 功能選單 ======")
    print("1. 新增購買紀錄")
    print("2. 功能2（待定）")
    print("3. 功能3（待定）")
    print("4. 功能4（待定）")
    print("5. 離開程式")
    print("======================")

    number = int(input("請輸入數字 (1~5): "))

    if number == 1:
        # 新增購買紀錄
        date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
        datetime.datetime.strptime(date_str, '%Y-%m-%d')

        time_str = input("請輸入時間 (格式：HH:MM): ")
        datetime.datetime.strptime(time_str, '%H:%M')

        item = input("請輸入品項: ")
        amount = float(input("請輸入金額: "))

        # 更新總支出
        total += amount

        # 新增到 Google Sheet
        new_row = [date_str, time_str, item, amount, total]
        worksheet.append_row(new_row, value_input_option='USER_ENTERED')

        print("✅ 資料已成功寫入 Google 工作表！")

    elif number == 2:
        print("👉 功能3 還沒做，可以在這裡加上邏輯")
    elif number == 3:
        print("👉 功能3 還沒做，可以在這裡加上邏輯")
    elif number == 4:
        print("👉 功能4 還沒做，可以在這裡加上邏輯")
    elif number == 5:
        print("👋 程式結束，再見！")
    else:
        print("⚠️ 請輸入 1~5 之間的數字")
# Out:
# ====== 功能選單 ======
# 1. 新增購買紀錄
# 2. 功能2（待定）
# 3. 功能3（待定）
# 4. 功能4（待定）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 3
# 👉 功能3 還沒做，可以在這裡加上邏輯
#
# ====== 功能選單 ======
# 1. 新增購買紀錄
# 2. 功能2（待定）
# 3. 功能3（待定）
# 4. 功能4（待定）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 5
# 👋 程式結束，再見！

# %%
import datetime
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd
import matplotlib.pyplot as plt

# Google 驗證
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 連線到 Google Sheet
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing')
worksheet = gsheets.worksheet('工作表1')

# 讀取最後一筆「總支出」
rows = worksheet.get_all_values()
if len(rows) > 1 and rows[-1][4] != '':
    total = float(rows[-1][4])
else:
    total = 0

# while 迴圈：顯示選單
number = 0
while number != 5:
    print("\n====== 功能選單 ======")
    print("1. 新增購買紀錄")
    print("2. 顯示時間對消費金額圖表")
    print("3. 功能3（待定）")
    print("4. 功能4（待定）")
    print("5. 離開程式")
    print("======================")

    number = int(input("請輸入數字 (1~5): "))

    if number == 1:
        # 新增購買紀錄
        date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
        datetime.datetime.strptime(date_str, '%Y-%m-%d')

        time_str = input("請輸入時間 (格式：HH:MM): ")
        datetime.datetime.strptime(time_str, '%H:%M')

        item = input("請輸入品項: ")
        amount = float(input("請輸入金額: "))

        # 更新總支出
        total += amount

        # 新增到 Google Sheet
        new_row = [date_str, time_str, item, amount, total]
        worksheet.append_row(new_row, value_input_option='USER_ENTERED')

        print("✅ 資料已成功寫入 Google 工作表！")

    elif number == 2:
        print("📊 查詢統計結果...")

        # 重新讀取 Google Sheet 資料
        rows = worksheet.get_all_values()
        df = pd.DataFrame(rows[1:], columns=rows[0])  # 跳過標題列

        # 資料轉換
        df['金額'] = pd.to_numeric(df['金額'], errors='coerce')

        # 統計結果
        total_spent = df['金額'].sum()
        avg_spent = df['金額'].mean()
        count_spent = df['金額'].count()
        top_item = df['品項'].mode()[0] if not df['品項'].mode().empty else "無"

        print("====== 統計結果 ======")
        print(f"總消費金額：{total_spent:.2f}")
        print(f"平均每筆消費：{avg_spent:.2f}")
        print(f"消費次數：{count_spent}")
        print(f"最常購買品項：{top_item}")
        print("======================")

    elif number == 3:
        print("👉 功能3 還沒做，可以在這裡加上邏輯")
    elif number == 4:
        print("👉 功能4 還沒做，可以在這裡加上邏輯")
    elif number == 5:
        print("👋 程式結束，再見！")
    else:
        print("⚠️ 請輸入 1~5 之間的數字")
# Out:
# ====== 功能選單 ======
# 1. 新增購買紀錄
# 2. 顯示時間對消費金額圖表
# 3. 功能3（待定）
# 4. 功能4（待定）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 1
# 請輸入日期 (格式：YYYY-MM-DD): 2027-10-11
# 請輸入時間 (格式：HH:MM): 19:20
# 請輸入品項: J
# 請輸入金額: 80
# ✅ 資料已成功寫入 Google 工作表！
#
# ====== 功能選單 ======
# 1. 新增購買紀錄
# 2. 顯示時間對消費金額圖表
# 3. 功能3（待定）
# 4. 功能4（待定）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 2
# 📊 查詢統計結果...
# ====== 統計結果 ======
# 總消費金額：310.00
# 平均每筆消費：77.50
# 消費次數：4
# 最常購買品項：E
# ...
#
# ====== 功能選單 ======
# 1. 新增購買紀錄
# 2. 顯示時間對消費金額圖表
# 3. 功能3（待定）
# 4. 功能4（待定）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 5
# 👋 程式結束，再見！

# %%
import datetime
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# Google 驗證
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 連線到 Google Sheet
gsheets = gc.open_by_url(
    'https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing'
)

# 建立兩個 sheet（計劃、紀錄），如果不存在就新增
try:
    plan_sheet = gsheets.worksheet('計劃')
except:
    plan_sheet = gsheets.add_worksheet(title="計劃", rows="100", cols="10")
    plan_sheet.append_row(["生活費", "食", "衣", "住", "行", "樂", "其他"])

try:
    record_sheet = gsheets.worksheet('紀錄')
except:
    record_sheet = gsheets.add_worksheet(title="紀錄", rows="1000", cols="10")
    record_sheet.append_row(["日期", "分類", "品項", "金額"])

# ========= 第一步：輸入計劃 =========
print("💡 請先設定本期生活費計劃：")
budget = float(input("請輸入生活費總金額: "))

categories = ["食", "衣", "住", "行", "樂", "其他"]
allocations = {}
for c in categories:
    allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))

plan_sheet.append_row([budget] + [allocations[c] for c in categories])
print("✅ 已儲存生活費計劃！")

# ========= 功能選單 =========
number = 0
while number != 5:
    print("\n====== 功能選單 ======")
    print("1. 新增消費紀錄")
    print("2. 刪除一筆紀錄")
    print("3. 查詢支出情況")
    print("4. 結算（待開發）")
    print("5. 離開程式")
    print("======================")

    number = int(input("請輸入數字 (1~5): "))

    if number == 1:
        # 新增紀錄
        date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
        datetime.datetime.strptime(date_str, '%Y-%m-%d')  # 驗證格式

        print("請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他")
        cat_num = int(input("輸入數字 (1~6): "))
        category = categories[cat_num - 1]

        item = input("請輸入品項: ")
        amount = float(input("請輸入金額: "))

        record_sheet.append_row([date_str, category, item, amount], value_input_option='USER_ENTERED')
        print("✅ 資料已成功寫入 Google 工作表！")

    elif number == 2:
        # 刪除紀錄
        rows = record_sheet.get_all_values()
        df = pd.DataFrame(rows[1:], columns=rows[0])
        print("\n目前紀錄：")
        print(df)

        row_num = int(input("請輸入要刪除的紀錄編號 (從 2 開始，因為第 1 行是標題): "))
        record_sheet.delete_rows(row_num)
        print("✅ 已刪除該筆紀錄！")

    elif number == 3:
        # 查詢支出情況
        rows = record_sheet.get_all_values()
        if len(rows) <= 1:
            print("⚠️ 尚無任何紀錄")
        else:
            df = pd.DataFrame(rows[1:], columns=rows[0])
            df['金額'] = pd.to_numeric(df['金額'], errors='coerce')

            total_spent = df['金額'].sum()
            by_category = df.groupby("分類")['金額'].sum()

            print("\n====== 支出情況 ======")
            print(f"總支出：{total_spent:.2f}")
            for c in categories:
                spent = by_category[c] if c in by_category else 0
                print(f"{c}：{spent:.2f}")
            print("======================")

    elif number == 4:
        print("👉 結算功能還沒做（之後可以加入剩餘預算、超支狀況分析）")

    elif number == 5:
        print("👋 程式結束，再見！")

    else:
        print("⚠️ 請輸入 1~5 之間的數字")
# Out:
# 💡 請先設定本期生活費計劃：
# 請輸入生活費總金額: 8000
# 請輸入分配在【食】的金額: 2000
# 請輸入分配在【衣】的金額: 500
# 請輸入分配在【住】的金額: 2000
# 請輸入分配在【行】的金額: 1000
# 請輸入分配在【樂】的金額: 500
# 請輸入分配在【其他】的金額: 2000
# ✅ 已儲存生活費計劃！
#
# ====== 功能選單 ======
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 1
# 請輸入日期 (格式：YYYY-MM-DD): 2025-09-11
# 請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他
# 輸入數字 (1~6): 2
# 請輸入品項: 衣服
# 請輸入金額: 290
# ✅ 資料已成功寫入 Google 工作表！
#
# ====== 功能選單 ======
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 2
#
# 目前紀錄：
#            日期 分類  品項   金額
# 0  2025-09-11  衣  衣服  290
# 請輸入要刪除的紀錄編號 (從 2 開始，因為第 1 行是標題): 2
# ✅ 已刪除該筆紀錄！
#
# ====== 功能選單 ======
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 1
# 請輸入日期 (格式：YYYY-MM-DD): 2022-08-11
# 請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他
# 輸入數字 (1~6): 1
# 請輸入品項: 111
# 請輸入金額: 100
# ✅ 資料已成功寫入 Google 工作表！
#
# ====== 功能選單 ======
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 5
# 👋 程式結束，再見！

# %%
import datetime
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# Google 驗證
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 連線到 Google Sheet
gsheets = gc.open_by_url(
    'https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing'
)

# 建立兩個 sheet（計劃、紀錄），如果不存在就新增
try:
    plan_sheet = gsheets.worksheet('計劃')
except:
    plan_sheet = gsheets.add_worksheet(title="計劃", rows="100", cols="10")
    plan_sheet.append_row(["生活費", "食", "衣", "住", "行", "樂", "其他"])

try:
    record_sheet = gsheets.worksheet('紀錄')
except:
    record_sheet = gsheets.add_worksheet(title="紀錄", rows="1000", cols="10")
    record_sheet.append_row(["日期", "分類", "品項", "金額"])

# ========= 第一步：輸入計劃 =========
print("💡 請先設定本期生活費計劃：")
budget = float(input("請輸入生活費總金額: "))

categories = ["食", "衣", "住", "行", "樂", "其他"]
allocations = {}
for c in categories:
    allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))

# 把計劃存到 Google Sheet
plan_sheet.append_row([budget] + [allocations[c] for c in categories])
print("✅ 已儲存生活費計劃！")

# ========= 功能選單 =========
number = 0
while number != 5:
    print("\n====== 功能選單 ======")
    print("1. 新增消費紀錄")
    print("2. 刪除一筆紀錄")
    print("3. 查詢支出情況")
    print("4. 結算（待開發）")
    print("5. 離開程式")
    print("======================")

    number = int(input("請輸入數字 (1~5): "))

    if number == 1:
        # 新增紀錄
        date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
        datetime.datetime.strptime(date_str, '%Y-%m-%d')  # 驗證格式

        print("請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他")
        cat_num = int(input("輸入數字 (1~6): "))
        category = categories[cat_num - 1]

        item = input("請輸入品項: ")
        amount = float(input("請輸入金額: "))

        record_sheet.append_row([date_str, category, item, amount], value_input_option='USER_ENTERED')
        print("✅ 消費紀錄已成功寫入 Google 工作表！")

    elif number == 2:
        # 刪除紀錄
        rows = record_sheet.get_all_values()
        df = pd.DataFrame(rows[1:], columns=rows[0])
        print("\n目前紀錄：")
        print(df)

        row_num = int(input("請輸入要刪除的紀錄編號 (從 2 開始，因為第 1 行是標題): "))
        record_sheet.delete_rows(row_num)
        print("✅ 已刪除該筆紀錄！")

    elif number == 3:
        # 查詢支出情況
        rows = record_sheet.get_all_values()
        if len(rows) <= 1:
            print("⚠️ 尚無任何紀錄")
        else:
            df = pd.DataFrame(rows[1:], columns=rows[0])
            df['金額'] = pd.to_numeric(df['金額'], errors='coerce')

            total_spent = df['金額'].sum()
            by_category = df.groupby("分類")['金額'].sum()

            print("\n====== 支出情況 ======")
            print(f"總支出：{total_spent:.2f}")
            for c in categories:
                spent = by_category[c] if c in by_category else 0
                print(f"{c}：{spent:.2f}")
            print("======================")

    elif number == 4:
        print("👉 結算功能還沒做（之後可以加入剩餘預算、超支狀況分析）")

    elif number == 5:
        print("👋 程式結束，再見！")

    else:
        print("⚠️ 請輸入 1~5 之間的數字")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1558714772.py in <cell line: 0>()
#      18 try:
# ---> 19     plan_sheet = gsheets.worksheet('計劃')
#      20 except:
#
# /usr/local/lib/python3.12/dist-packages/gspread/spreadsheet.py in worksheet(self, title)
#     324         """
# --> 325         sheet_data = self.fetch_sheet_metadata()
#     326         try:
#
# /usr/local/lib/python3.12/dist-packages/gspread/spreadsheet.py in fetch_sheet_metadata(self, params)
#     229         """
# --> 230         return self.client.fetch_sheet_metadata(self.id, params=params)
#     231
#
# /usr/local/lib/python3.12/dist-packages/gspread/http_client.py in fetch_sheet_metadata(self, id, params)
#     304
# --> 305         r = self.request("get", url, params=params)
#     306
#
# ...

# %%
import datetime
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# Google 驗證
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 連線到 Google Sheet
gsheets = gc.open_by_url(
    'https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing'
)

# 建立兩個 sheet（計劃、紀錄），如果不存在就新增
try:
    plan_sheet = gsheets.worksheet('計劃')
except:
    plan_sheet = gsheets.add_worksheet(title="計劃", rows="100", cols="10")
    plan_sheet.append_row(["生活費", "食", "衣", "住", "行", "樂", "其他"])

try:
    record_sheet = gsheets.worksheet('紀錄')
except:
    record_sheet = gsheets.add_worksheet(title="紀錄", rows="1000", cols="10")
    record_sheet.append_row(["日期", "分類", "品項", "金額", "總金額"])

# ========= 第一步：輸入計劃 =========
print("💡 請先設定本期生活費計劃：")

categories = ["食", "衣", "住", "行", "樂", "其他"]

# 防呆：確保各分類加總等於生活費
while True:
    budget = float(input("請輸入生活費總金額: "))
    allocations = {}
    total_alloc = 0
    for c in categories:
        allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))
        total_alloc += allocations[c]
    if total_alloc != budget:
        print(f"⚠️ 分配總和 {total_alloc} 不等於生活費 {budget}，請重新輸入！\n")
    else:
        break

plan_sheet.append_row([budget] + [allocations[c] for c in categories])
print("✅ 已儲存生活費計劃！\n")

# ========= 功能選單 =========
number = 0
while number != 5:
    print("\n====== 功能選單 ======")
    print("1. 新增消費紀錄")
    print("2. 刪除一筆紀錄")
    print("3. 查詢支出情況")
    print("4. 結算（待開發）")
    print("5. 離開程式")
    print("======================")

    number = int(input("請輸入數字 (1~5): "))

    if number == 1:
        # 新增紀錄
        date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
        # 統一格式 YYYY/MM/DD
        date_obj = datetime.datetime.strptime(date_str, '%Y-%m-%d')
        date_str = date_obj.strftime("%Y/%m/%d")  # 2025/04/04

        print("請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他")
        cat_num = int(input("輸入數字 (1~6): "))
        category = categories[cat_num - 1]

        item = input("請輸入品項: ")
        amount = float(input("請輸入金額: "))

        # 更新累積總金額
        total_spent += amount

        record_sheet.append_row(
            [date_str, category, item, amount, total_spent],
            value_input_option='USER_ENTERED'
        )
        print("✅ 消費紀錄已成功寫入 Google 工作表！")

    elif number == 2:
        # 刪除紀錄
        rows = record_sheet.get_all_values()
        df = pd.DataFrame(rows[1:], columns=rows[0])

        if df.empty:
            print("⚠️ 尚無任何紀錄")
        else:
            print("\n目前紀錄：")
            print(df)  # 顯示 DataFrame，index 會是 0,1,2...

            idx = int(input("請輸入要刪除的編號 (從 0 開始): "))

            # Google Sheet 的實際行號 = pandas index + 2
            row_num = idx + 2
            record_sheet.delete_rows(row_num)

            print(f"✅ 已刪除第 {idx} 筆紀錄！")

            # 重新計算總金額，並更新表單
            rows = record_sheet.get_all_values()
            if len(rows) > 1:
                df = pd.DataFrame(rows[1:], columns=rows[0])
                df['金額'] = pd.to_numeric(df['金額'], errors='coerce')
                df['總金額'] = df['金額'].cumsum()
                record_sheet.clear()
                record_sheet.append_row(["日期", "分類", "品項", "金額", "總金額"])
                for r in df.values.tolist():
                    record_sheet.append_row(r, value_input_option='USER_ENTERED')
                total_spent = df['總金額'].iloc[-1]
            else:
                total_spent = 0.0

    elif number == 3:
        # 查詢支出情況
        rows = record_sheet.get_all_values()
        if len(rows) <= 1:
            print("⚠️ 尚無任何紀錄")
        else:
            df = pd.DataFrame(rows[1:], columns=rows[0])
            df['金額'] = pd.to_numeric(df['金額'], errors='coerce')
            df['總金額'] = pd.to_numeric(df['總金額'], errors='coerce')

            total_spent = df['金額'].sum()
            by_category = df.groupby("分類")['金額'].sum()

            print("\n====== 支出情況 ======")
            print(f"總支出：{total_spent:.2f}")
            for c in categories:
                spent = by_category[c] if c in by_category else 0
                print(f"{c}：{spent:.2f}")
            print("======================")

    elif number == 4:
        print("👉 結算功能還沒做（之後可以加入剩餘預算、超支狀況分析）")

    elif number == 5:
        print("👋 程式結束，再見！")

    else:
        print("⚠️ 請輸入 1~5 之間的數字")
# Out:
# 💡 請先設定本期生活費計劃：
# 請輸入生活費總金額: 600
# 請輸入分配在【食】的金額: 100
# 請輸入分配在【衣】的金額: 100
# 請輸入分配在【住】的金額: 100
# 請輸入分配在【行】的金額: 100
# 請輸入分配在【樂】的金額: 100
# 請輸入分配在【其他】的金額: 100
# ✅ 已儲存生活費計劃！
#
#
# ====== 功能選單 ======
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 1
# 請輸入日期 (格式：YYYY-MM-DD): 2025-04-04
# 請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他
# 輸入數字 (1~6): 2
# 請輸入品項: L
# 請輸入金額: 50
# ✅ 消費紀錄已成功寫入 Google 工作表！
#
# ====== 功能選單 ======
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 3
#
# ====== 支出情況 ======
# 總支出：55.00
# 食：0.00
# 衣：50.00
# 住：5.00
# 行：0.00
# 樂：0.00
# 其他：0.00
# ...
#
# ====== 功能選單 ======
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (1~5): 5
# 👋 程式結束，再見！

# %%
import datetime
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# Google 驗證
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 連線到 Google Sheet
gsheets = gc.open_by_url(
    'https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing'
)

# 建立兩個 sheet（計劃、紀錄），如果不存在就新增
categories = ["食", "衣", "住", "行", "樂", "其他"]

try:
    plan_sheet = gsheets.worksheet('計劃')
except:
    plan_sheet = gsheets.add_worksheet(title="計劃", rows="100", cols="10")
    plan_sheet.append_row(["生活費"] + categories)

try:
    record_sheet = gsheets.worksheet('紀錄')
except:
    record_sheet = gsheets.add_worksheet(title="紀錄", rows="1000", cols="10")
    record_sheet.append_row(["日期", "分類", "品項", "金額", "總金額"])

# ========= 檢查是否已有計劃 =========
plan_rows = plan_sheet.get_all_values()
if len(plan_rows) > 1:  # 除標題列外至少有一行
    print("📌 已存在生活費計劃，使用現有計劃")
    existing_budget = float(plan_rows[-1][0])
    existing_allocations = dict(zip(categories, map(float, plan_rows[-1][1:])))
else:
    # 如果沒有計劃，要求輸入
    while True:
        budget = float(input("請輸入生活費總金額: "))
        allocations = {}
        total_alloc = 0
        for c in categories:
            allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))
            total_alloc += allocations[c]
        if total_alloc != budget:
            print(f"⚠️ 分配總和 {total_alloc} 不等於生活費 {budget}，請重新輸入！\n")
        else:
            break
    plan_sheet.append_row([budget] + [allocations[c] for c in categories])
    print("✅ 已儲存生活費計劃！")

# ========= 讀取目前紀錄，計算總金額 =========
rows = record_sheet.get_all_values()
if len(rows) > 1 and rows[-1][4] != "":
    total_spent = float(rows[-1][4])
else:
    total_spent = 0.0

# ========= 功能選單 =========
number = -1
while number != 5:
    print("\n====== 功能選單 ======")
    print("0. 修改計劃")
    print("1. 新增消費紀錄")
    print("2. 刪除一筆紀錄")
    print("3. 查詢支出情況")
    print("4. 結算（待開發）")
    print("5. 離開程式")
    print("======================")

    try:
        number = int(input("請輸入數字 (0~5): "))
    except:
        print("⚠️ 請輸入 0~5 的數字")
        continue

    if number == 0:
        # 修改計劃
        plan_rows = plan_sheet.get_all_values()
        if len(plan_rows) <= 1:
            print("⚠️ 尚無任何計劃，請先建立計劃")
        else:
            df_plan = pd.DataFrame(plan_rows[1:], columns=plan_rows[0])
            print("目前計劃：")
            print(df_plan)

            while True:
                budget = float(input("請輸入新的生活費總金額: "))
                allocations = {}
                total_alloc = 0
                for c in categories:
                    allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))
                    total_alloc += allocations[c]
                if total_alloc != budget:
                    print(f"⚠️ 分配總和 {total_alloc} 不等於生活費 {budget}，請重新輸入！\n")
                else:
                    break

            # 清空舊計劃並寫入新計劃
            plan_sheet.clear()
            plan_sheet.append_row(["生活費"] + categories)
            plan_sheet.append_row([budget] + [allocations[c] for c in categories])
            print("✅ 計劃已更新！")

    elif number == 1:
        # 新增紀錄
        date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
        try:
            date_obj = datetime.datetime.strptime(date_str, '%Y-%m-%d')
            date_str = date_obj.strftime("%Y/%m/%d")  # YYYY/MM/DD
        except:
            print("⚠️ 日期格式錯誤")
            continue

        print("請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他")
        try:
            cat_num = int(input("輸入數字 (1~6): "))
            if cat_num < 1 or cat_num > 6:
                print("⚠️ 請輸入 1~6 的數字")
                continue
        except:
            print("⚠️ 請輸入 1~6 的數字")
            continue
        category = categories[cat_num - 1]

        item = input("請輸入品項: ")
        try:
            amount = float(input("請輸入金額: "))
        except:
            print("⚠️ 金額格式錯誤")
            continue

        total_spent += amount
        record_sheet.append_row(
            [date_str, category, item, amount, total_spent],
            value_input_option='USER_ENTERED'
        )
        print("✅ 消費紀錄已成功寫入 Google 工作表！")

    elif number == 2:
        # 刪除紀錄
        rows = record_sheet.get_all_values()
        df = pd.DataFrame(rows[1:], columns=rows[0])

        if df.empty:
            print("⚠️ 尚無任何紀錄")
        else:
            print("\n目前紀錄：")
            print(df)

            try:
                idx = int(input("請輸入要刪除的編號 (從 0 開始): "))
                if idx < 0 or idx >= len(df):
                    print("⚠️ 編號超出範圍")
                    continue
            except:
                print("⚠️ 請輸入數字")
                continue

            row_num = idx + 2  # Google Sheet 實際行號
            record_sheet.delete_rows(row_num)
            print(f"✅ 已刪除第 {idx} 筆紀錄！")

            # 重新計算總金額
            rows = record_sheet.get_all_values()
            if len(rows) > 1:
                df = pd.DataFrame(rows[1:], columns=rows[0])
                df['金額'] = pd.to_numeric(df['金額'], errors='coerce')
                df['總金額'] = df['金額'].cumsum()
                record_sheet.clear()
                record_sheet.append_row(["日期", "分類", "品項", "金額", "總金額"])
                for r in df.values.tolist():
                    record_sheet.append_row(r, value_input_option='USER_ENTERED')
                total_spent = df['總金額'].iloc[-1]
            else:
                total_spent = 0.0

    elif number == 3:
        # 查詢支出情況
        rows = record_sheet.get_all_values()
        if len(rows) <= 1:
            print("⚠️ 尚無任何紀錄")
        else:
            df = pd.DataFrame(rows[1:], columns=rows[0])
            df['金額'] = pd.to_numeric(df['金額'], errors='coerce')
            df['總金額'] = pd.to_numeric(df['總金額'], errors='coerce')

            total_spent = df['金額'].sum()
            by_category = df.groupby("分類")['金額'].sum()

            print("\n====== 支出情況 ======")
            print(f"總支出：{total_spent:.2f}")
            for c in categories:
                spent = by_category[c] if c in by_category else 0
                print(f"{c}：{spent:.2f}")
            print("======================")

    elif number == 4:
        print("👉 結算功能還沒做（之後可以加入剩餘預算、超支狀況分析）")

    elif number == 5:
        print("👋 程式結束，再見！")

    else:
        print("⚠️ 請輸入 0~5 之間的數字")
# Out:
# 請輸入生活費總金額: 8000
# 請輸入分配在【食】的金額: 3000
# 請輸入分配在【衣】的金額: 500
# 請輸入分配在【住】的金額: 500
# 請輸入分配在【行】的金額: 1000
# 請輸入分配在【樂】的金額: 1000
# 請輸入分配在【其他】的金額: 2000
# ✅ 已儲存生活費計劃！
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 1
# 請輸入日期 (格式：YYYY-MM-DD): 2024-05-01
# 請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他
# 輸入數字 (1~6): 1
# 請輸入品項: K
# 請輸入金額: 200
# ✅ 消費紀錄已成功寫入 Google 工作表！
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 1
# 請輸入日期 (格式：YYYY-MM-DD): 2025-07-08
# 請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他
# 輸入數字 (1~6): 3
# 請輸入品項: 200
# 請輸入金額: 200
# ✅ 消費紀錄已成功寫入 Google 工作表！
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 1
# 請輸入日期 (格式：YYYY-MM-DD): 2025-09-09
# 請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他
# 輸入數字 (1~6): 6
# 請輸入品項: G
# 請輸入金額: 300
# ✅ 消費紀錄已成功寫入 Google 工作表！
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...

# %%
import datetime
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# Google 驗證
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 連線到 Google Sheet
gsheets = gc.open_by_url(
    'https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing'
)

# 建立兩個 sheet（計劃、紀錄），如果不存在就新增
categories = ["食", "衣", "住", "行", "樂", "其他"]

try:
    plan_sheet = gsheets.worksheet('計劃')
except:
    plan_sheet = gsheets.add_worksheet(title="計劃", rows="100", cols="10")
    plan_sheet.append_row(["生活費"] + categories)

try:
    record_sheet = gsheets.worksheet('紀錄')
except:
    record_sheet = gsheets.add_worksheet(title="紀錄", rows="1000", cols="10")
    record_sheet.append_row(["日期", "分類", "品項", "金額", "總金額"])

# ========= 檢查是否已有計劃 =========
plan_rows = plan_sheet.get_all_values()
if len(plan_rows) > 1:  # 除標題列外至少有一行
    print("📌 已存在生活費計劃，使用現有計劃")
    existing_budget = float(plan_rows[-1][0])
    existing_allocations = dict(zip(categories, map(float, plan_rows[-1][1:])))
else:
    # 如果沒有計劃，要求輸入
    while True:
        budget = float(input("請輸入生活費總金額: "))
        allocations = {}
        total_alloc = 0
        for c in categories:
            allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))
            total_alloc += allocations[c]
        if total_alloc != budget:
            print(f"⚠️ 分配總和 {total_alloc} 不等於生活費 {budget}，請重新輸入！\n")
        else:
            break
    plan_sheet.append_row([budget] + [allocations[c] for c in categories])
    print("✅ 已儲存生活費計劃！")

# ========= 讀取目前紀錄，計算總金額 =========
rows = record_sheet.get_all_values()
if len(rows) > 1 and rows[-1][4] != "":
    total_spent = float(rows[-1][4])
else:
    total_spent = 0.0

# ========= 功能選單 =========
number = -1
while number != 5:
    print("\n====== 功能選單 ======")
    print("0. 修改計劃")
    print("1. 新增消費紀錄")
    print("2. 刪除一筆紀錄")
    print("3. 查詢支出情況")
    print("4. 結算報告")
    print("5. 離開程式")
    print("======================")

    try:
        number = int(input("請輸入數字 (0~5): "))
    except:
        print("⚠️ 請輸入 0~5 的數字")
        continue

    if number == 0:
        # 修改計劃
        plan_rows = plan_sheet.get_all_values()
        if len(plan_rows) <= 1:
            print("⚠️ 尚無任何計劃，請先建立計劃")
        else:
            df_plan = pd.DataFrame(plan_rows[1:], columns=plan_rows[0])
            print("目前計劃：")
            print(df_plan)

            while True:
                budget = float(input("請輸入新的生活費總金額: "))
                allocations = {}
                total_alloc = 0
                for c in categories:
                    allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))
                    total_alloc += allocations[c]
                if total_alloc != budget:
                    print(f"⚠️ 分配總和 {total_alloc} 不等於生活費 {budget}，請重新輸入！\n")
                else:
                    break

            # 清空舊計劃並寫入新計劃
            plan_sheet.clear()
            plan_sheet.append_row(["生活費"] + categories)
            plan_sheet.append_row([budget] + [allocations[c] for c in categories])
            print("✅ 計劃已更新！")

    elif number == 1:
        # 新增紀錄
        date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
        try:
            date_obj = datetime.datetime.strptime(date_str, '%Y-%m-%d')
            date_str = date_obj.strftime("%Y/%m/%d")  # YYYY/MM/DD
        except:
            print("⚠️ 日期格式錯誤")
            continue

        print("請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他")
        try:
            cat_num = int(input("輸入數字 (1~6): "))
            if cat_num < 1 or cat_num > 6:
                print("⚠️ 請輸入 1~6 的數字")
                continue
        except:
            print("⚠️ 請輸入 1~6 的數字")
            continue
        category = categories[cat_num - 1]

        item = input("請輸入品項: ")
        try:
            amount = float(input("請輸入金額: "))
        except:
            print("⚠️ 金額格式錯誤")
            continue

        total_spent += amount
        record_sheet.append_row(
            [date_str, category, item, amount, total_spent],
            value_input_option='USER_ENTERED'
        )
        print("✅ 消費紀錄已成功寫入 Google 工作表！")

    elif number == 2:
        # 刪除紀錄
        rows = record_sheet.get_all_values()
        df = pd.DataFrame(rows[1:], columns=rows[0])

        if df.empty:
            print("⚠️ 尚無任何紀錄")
        else:
            print("\n目前紀錄：")
            print(df)

            try:
                idx = int(input("請輸入要刪除的編號 (從 0 開始): "))
                if idx < 0 or idx >= len(df):
                    print("⚠️ 編號超出範圍")
                    continue
            except:
                print("⚠️ 請輸入數字")
                continue

            row_num = idx + 2  # Google Sheet 實際行號
            record_sheet.delete_rows(row_num)
            print(f"✅ 已刪除第 {idx} 筆紀錄！")

            # 重新計算總金額
            rows = record_sheet.get_all_values()
            if len(rows) > 1:
                df = pd.DataFrame(rows[1:], columns=rows[0])
                df['金額'] = pd.to_numeric(df['金額'], errors='coerce')
                df['總金額'] = df['金額'].cumsum()
                record_sheet.clear()
                record_sheet.append_row(["日期", "分類", "品項", "金額", "總金額"])
                for r in df.values.tolist():
                    record_sheet.append_row(r, value_input_option='USER_ENTERED')
                total_spent = df['總金額'].iloc[-1]
            else:
                total_spent = 0.0

    elif number == 3:
        # 查詢支出情況
        rows = record_sheet.get_all_values()
        if len(rows) <= 1:
            print("⚠️ 尚無任何紀錄")
        else:
            df = pd.DataFrame(rows[1:], columns=rows[0])
            df['金額'] = pd.to_numeric(df['金額'], errors='coerce')
            df['總金額'] = pd.to_numeric(df['總金額'], errors='coerce')

            total_spent = df['金額'].sum()
            by_category = df.groupby("分類")['金額'].sum()

            print("\n====== 支出情況 ======")
            print(f"總支出：{total_spent:.2f}")
            for c in categories:
                spent = by_category[c] if c in by_category else 0
                print(f"{c}：{spent:.2f}")
            print("======================")

    elif number == 4:
        print("📊 結算報告：")

        # 讀取計劃和紀錄
        plan_rows = plan_sheet.get_all_values()
        plan = list(map(float, plan_rows[-1][1:]))  # 各分類計畫金額
        df_plan = dict(zip(categories, plan))

        rows = record_sheet.get_all_values()
        if len(rows) <= 1:
            print("⚠️ 尚無任何紀錄")
            continue

        df = pd.DataFrame(rows[1:], columns=rows[0])
        df['金額'] = pd.to_numeric(df['金額'], errors='coerce')

        # 計算每個分類花費與剩餘
        by_category = df.groupby("分類")['金額'].sum()
        total_spent = df['金額'].sum()
        total_budget = sum(df_plan.values())
        total_remain = total_budget - total_spent

        category_status = {}
        print("\n=== 各分類支出情況 ===")
        for c in categories:
            spent = by_category[c] if c in by_category else 0
            remain = df_plan[c] - spent
            # 判斷標語
            if remain < -0.15 * df_plan[c]:
                slogan = "嚴重透支"
            elif abs(remain) <= 0.15 * df_plan[c]:
                slogan = "收支平衡"
            else:
                slogan = "有積蓄"
            category_status[c] = {'spent': spent, 'remain': remain, 'slogan': slogan}
            print(f"{c}: 花費 {spent:.2f}, 剩餘 {remain:.2f}, {slogan}")

        # 總金額
        print(f"\n總花費: {total_spent:.2f}, 總剩餘: {total_remain:.2f}")

        # 小提醒 / 整體回饋
        over = sum(1 for c in categories if category_status[c]['remain'] < 0)
        under = sum(1 for c in categories if category_status[c]['remain'] > 0)

        print("\n=== 整體回饋 ===")
        if over == 0:
            print("👏 全部分類都有積蓄，很棒哦！")
        elif over > 0 and under > 0 and total_remain >= 0:
            print("💡 部分分類超支，但總體還有剩餘，建議檢討超支的部分哦!")
        elif over > 0 and under > 0 and total_remain < 0:
            print("⚠️ 部分分類超支且總體透支，可能需要重新規劃哦！")
        elif under >= len(categories) // 2:
            print("😊 大部分分類都有積蓄，維持目前策略就可以啦!")
        elif over >= len(categories) // 2:
            print("⚠️ 大部分分類超支，建議控制支出或重新分配預算哦!")

    elif number == 5:
        print("👋 程式結束，再見！")

    else:
        print("⚠️ 請輸入 0~5 之間的數字")
# Out:
# 📌 已存在生活費計劃，使用現有計劃
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 3
#
# ====== 支出情況 ======
# 總支出：500.00
# 食：200.00
# 衣：0.00
# 住：0.00
# 行：0.00
# 樂：0.00
# 其他：300.00
# ...
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 1
# 請輸入日期 (格式：YYYY-MM-DD): 2025-11-12
# 請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他
# 輸入數字 (1~6): 3
# 請輸入品項: W
# 請輸入金額: 700
# ✅ 消費紀錄已成功寫入 Google 工作表！
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 4
# 📊 結算報告：
#
# === 各分類支出情況 ===
# 食: 花費 200.00, 剩餘 2800.00, 有積蓄
# 衣: 花費 0.00, 剩餘 500.00, 有積蓄
# 住: 花費 700.00, 剩餘 -200.00, 嚴重透支
# 行: 花費 0.00, 剩餘 1000.00, 有積蓄
# 樂: 花費 0.00, 剩餘 1000.00, 有積蓄
# 其他: 花費 300.00, 剩餘 1700.00, 有積蓄
#
# 總花費: 1200.00, 總剩餘: 6800.00
#
# === 小提醒 / 整體回饋 ===
# 💡 部分分類超支，但總體還有剩餘，建議檢討超支分類
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算（待開發）
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 1
# ...

# %% [markdown]
# # **最終程式碼**

# %%
import datetime
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd

# Google 驗證
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# 連線到 Google Sheet
gsheets = gc.open_by_url(
    'https://docs.google.com/spreadsheets/d/1W0EMUIir8dF3LhCMafo8CRo1B_m_0EB7YRMpLvO5Ru8/edit?usp=sharing'
)

# 建立兩個 sheet（計劃、紀錄），如果不存在就新增
categories = ["食", "衣", "住", "行", "樂", "其他"]

try:
    plan_sheet = gsheets.worksheet('計劃')
except:
    plan_sheet = gsheets.add_worksheet(title="計劃", rows="100", cols="10")
    plan_sheet.append_row(["生活費"] + categories)

try:
    record_sheet = gsheets.worksheet('紀錄')
except:
    record_sheet = gsheets.add_worksheet(title="紀錄", rows="1000", cols="10")
    record_sheet.append_row(["日期", "分類", "品項", "金額", "總金額"])

# ========= 檢查是否已有計劃 =========
plan_rows = plan_sheet.get_all_values()
if len(plan_rows) > 1:  # 除標題列外至少有一行
    print("📌 已存在生活費計劃，使用現有計劃")
    existing_budget = float(plan_rows[-1][0])
    existing_allocations = dict(zip(categories, map(float, plan_rows[-1][1:])))
else:
    # 如果沒有計劃，要求輸入
    while True:
        budget = float(input("請輸入生活費總金額: "))
        allocations = {}
        total_alloc = 0
        for c in categories:
            allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))
            total_alloc += allocations[c]
        if total_alloc != budget:
            print(f"⚠️ 分配總和 {total_alloc} 不等於生活費 {budget}，請重新輸入！\n")
        else:
            break
    plan_sheet.append_row([budget] + [allocations[c] for c in categories])
    print("✅ 已儲存生活費計劃！")

# ========= 讀取目前紀錄，計算總金額 =========
rows = record_sheet.get_all_values()
if len(rows) > 1 and rows[-1][4] != "":
    total_spent = float(rows[-1][4])
else:
    total_spent = 0.0

# ========= 功能選單 =========
number = -1
while number != 5:
    print("\n====== 功能選單 ======")
    print("0. 修改計劃")
    print("1. 新增消費紀錄")
    print("2. 刪除一筆紀錄")
    print("3. 查詢支出情況")
    print("4. 結算報告")
    print("5. 離開程式")
    print("======================")

    try:
        number = int(input("請輸入數字 (0~5): "))
    except:
        print("⚠️ 請輸入 0~5 的數字")
        continue

    if number == 0:
        # 修改計劃
        plan_rows = plan_sheet.get_all_values()
        if len(plan_rows) <= 1:
            print("⚠️ 尚無任何計劃，請先建立計劃")
        else:
            df_plan = pd.DataFrame(plan_rows[1:], columns=plan_rows[0])
            print("目前計劃：")
            print(df_plan)

            while True:
                budget = float(input("請輸入新的生活費總金額: "))
                allocations = {}
                total_alloc = 0
                for c in categories:
                    allocations[c] = float(input(f"請輸入分配在【{c}】的金額: "))
                    total_alloc += allocations[c]
                if total_alloc != budget:
                    print(f"⚠️ 分配總和 {total_alloc} 不等於生活費 {budget}，請重新輸入！\n")
                else:
                    break

            # 清空舊計劃並寫入新計劃
            plan_sheet.clear()
            plan_sheet.append_row(["生活費"] + categories)
            plan_sheet.append_row([budget] + [allocations[c] for c in categories])
            print("✅ 計劃已更新！")

    elif number == 1:
        # 新增紀錄
        date_str = input("請輸入日期 (格式：YYYY-MM-DD): ")
        try:
            date_obj = datetime.datetime.strptime(date_str, '%Y-%m-%d')
            date_str = date_obj.strftime("%Y/%m/%d")  # YYYY/MM/DD
        except:
            print("⚠️ 日期格式錯誤")
            continue

        print("請選擇分類：1.食  2.衣  3.住  4.行  5.樂  6.其他")
        try:
            cat_num = int(input("輸入數字 (1~6): "))
            if cat_num < 1 or cat_num > 6:
                print("⚠️ 請輸入 1~6 的數字")
                continue
        except:
            print("⚠️ 請輸入 1~6 的數字")
            continue
        category = categories[cat_num - 1]

        item = input("請輸入品項: ")
        try:
            amount = float(input("請輸入金額: "))
        except:
            print("⚠️ 金額格式錯誤")
            continue

        total_spent += amount
        record_sheet.append_row(
            [date_str, category, item, amount, total_spent],
            value_input_option='USER_ENTERED'
        )
        print("✅ 消費紀錄已成功寫入 Google 工作表！")

    elif number == 2:
        # 刪除紀錄
        rows = record_sheet.get_all_values()
        df = pd.DataFrame(rows[1:], columns=rows[0])

        if df.empty:
            print("⚠️ 尚無任何紀錄")
        else:
            print("\n目前紀錄：")
            print(df)

            try:
                idx = int(input("請輸入要刪除的編號 (從 0 開始): "))
                if idx < 0 or idx >= len(df):
                    print("⚠️ 編號超出範圍")
                    continue
            except:
                print("⚠️ 請輸入數字")
                continue

            row_num = idx + 2  # Google Sheet 實際行號
            record_sheet.delete_rows(row_num)
            print(f"✅ 已刪除第 {idx} 筆紀錄！")

            # 重新計算總金額
            rows = record_sheet.get_all_values()
            if len(rows) > 1:
                df = pd.DataFrame(rows[1:], columns=rows[0])
                df['金額'] = pd.to_numeric(df['金額'], errors='coerce')
                df['總金額'] = df['金額'].cumsum()
                record_sheet.clear()
                record_sheet.append_row(["日期", "分類", "品項", "金額", "總金額"])
                for r in df.values.tolist():
                    record_sheet.append_row(r, value_input_option='USER_ENTERED')
                total_spent = df['總金額'].iloc[-1]
            else:
                total_spent = 0.0

    elif number == 3:
        # 查詢支出情況
        rows = record_sheet.get_all_values()
        if len(rows) <= 1:
            print("⚠️ 尚無任何紀錄")
        else:
            df = pd.DataFrame(rows[1:], columns=rows[0])
            df['金額'] = pd.to_numeric(df['金額'], errors='coerce')

            total_spent = df['金額'].sum()
            by_category = df.groupby("分類")['金額'].sum()

            print("\n====== 支出情況 ======")
            print(f"總支出：{total_spent:.2f}")
            for c in categories:
                spent = by_category[c] if c in by_category else 0
                print(f"{c}：{spent:.2f}")
            print("======================")

    elif number == 4:
        print("📊 結算報告：")

        # 讀取計劃和紀錄
        plan_rows = plan_sheet.get_all_values()
        plan = list(map(float, plan_rows[-1][1:]))  # 各分類計畫金額
        df_plan = dict(zip(categories, plan))

        rows = record_sheet.get_all_values()
        if len(rows) <= 1:
            print("⚠️ 尚無任何紀錄")
            continue

        df = pd.DataFrame(rows[1:], columns=rows[0])
        df['金額'] = pd.to_numeric(df['金額'], errors='coerce')

        # 計算每個分類花費與剩餘
        by_category = df.groupby("分類")['金額'].sum()
        total_spent = df['金額'].sum()
        total_budget = sum(df_plan.values())
        total_remain = total_budget - total_spent

        category_status = {}
        report_data = [["分類", "花費", "剩餘", "標語"]]
        print("\n=== 各分類支出情況 ===")
        for c in categories:
            spent = by_category[c] if c in by_category else 0
            remain = df_plan[c] - spent
            if remain < -0.15 * df_plan[c]:
                slogan = "嚴重透支"
            elif abs(remain) <= 0.15 * df_plan[c]:
                slogan = "收支平衡"
            else:
                slogan = "有積蓄"
            category_status[c] = {'spent': spent, 'remain': remain, 'slogan': slogan}
            print(f"{c}: 花費 {spent:.2f}, 剩餘 {remain:.2f}, {slogan}")
            # 使用 float() 避免 gspread TypeError
            report_data.append([c, float(round(spent,2)), float(round(remain,2)), slogan])

        # 總花費、總剩餘
        print(f"\n總花費: {total_spent:.2f}, 總剩餘: {total_remain:.2f}")

        # 小提醒 / 整體回饋
        over = sum(1 for c in categories if category_status[c]['remain'] < 0)
        under = sum(1 for c in categories if category_status[c]['remain'] > 0)

        if over == 0:
            feedback = "👏 全部分類都有積蓄，很棒哦！"
        elif over > 0 and under > 0 and total_remain >= 0:
            feedback = "💡 部分分類超支，但總體還有剩餘，建議檢討超支的部分哦!"
        elif over > 0 and under > 0 and total_remain < 0:
            feedback = "⚠️ 部分分類超支且總體透支，可能需要重新規劃哦！"
        elif under >= len(categories) // 2:
            feedback = "😊 大部分分類都有積蓄，維持目前策略就可以啦!"
        elif over >= len(categories) // 2:
            feedback = "⚠️ 大部分分類超支，建議控制支出或重新分配預算哦!"

        print("\n=== 整體回饋 ===")
        print(feedback)
        # 總計行也轉成 float
        report_data.append(["總計", float(round(total_spent,2)), float(round(total_remain,2)), feedback])

        # ====== 寫入 Google Sheet ======
        try:
            report_sheet = gsheets.worksheet("結算報告")
            report_sheet.clear()  # 先清掉舊報告
        except:
            report_sheet = gsheets.add_worksheet(title="結算報告", rows="100", cols="10")

        for row in report_data:
            report_sheet.append_row(row, value_input_option='USER_ENTERED')
        print("✅ 已將結算報告寫入 Google Sheet 的 '結算報告' 分頁！")
    elif number == 5:
        print("👋 程式結束，再見！")

    else:
        print("⚠️ 請輸入 0~5 之間的數字")
# Out:
# 📌 已存在生活費計劃，使用現有計劃
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算報告
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 4
# 📊 結算報告：
#
# === 各分類支出情況 ===
# 食: 花費 200.00, 剩餘 2800.00, 有積蓄
# 衣: 花費 0.00, 剩餘 500.00, 有積蓄
# 住: 花費 700.00, 剩餘 -200.00, 嚴重透支
# 行: 花費 1100.00, 剩餘 -100.00, 收支平衡
# 樂: 花費 600.00, 剩餘 400.00, 有積蓄
# 其他: 花費 300.00, 剩餘 1700.00, 有積蓄
#
# 總花費: 2900.00, 總剩餘: 5100.00
#
# === 整體回饋 ===
# 💡 部分分類超支，但總體還有剩餘，建議檢討超支的部分哦!
# ✅ 已將結算報告寫入 Google Sheet 的 '結算報告' 分頁！
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算報告
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 2
#
# 目前紀錄：
#            日期  分類 品項    金額   總金額
# 0  2024-05-01   食  K   200   200
# 1  2025/09/09  其他  G   300   500
# 2  2025/11/12   住  W   700  1200
# 3  2025/11/30   行  R  1100  2300
# 4  2025/12/01   樂  V   600  2900
# 請輸入要刪除的編號 (從 0 開始): 2
# ✅ 已刪除第 2 筆紀錄！
#
# ====== 功能選單 ======
# 0. 修改計劃
# 1. 新增消費紀錄
# 2. 刪除一筆紀錄
# 3. 查詢支出情況
# 4. 結算報告
# 5. 離開程式
# ...
# 請輸入數字 (0~5): 3
#
# ====== 支出情況 ======
# 總支出：2200.00
# 食：200.00
# 衣：0.00
# ...
